# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

import re

# %%
df=pd.read_csv(r"C:\Users\Vijay Golliwar\EVcars-database(webscraping)",index_col=0)

# %%
df
# Out:
#          Brand                Model        Status  Battery_kWh   Range  \
# 0          BMW        iX3 50 xDrive     Available        108.7  610 km
# 1           MG      MG4 Electric 64     Available         61.7  360 km
# 2     Mercedes         Benz CLA 250     Available         85.0  585 km
# 3          BMW      iX xDrive40 BMW  Discontinued         71.0  360 km
# 4        Tesla         Model 3 Long     Available          NaN  580 km
# ...        ...                  ...           ...          ...     ...
# 1137       Kia            e-Niro 39  Discontinued         39.2  235 km
# 1138   Peugeot  e-Traveller Compact  Discontinued         46.3  185 km
# 1139      Ford       Mustang Mach-E  Discontinued         70.0  345 km
# 1140   Citroën                troën  Discontinued         46.3  185 km
# 1141   Citroën                troën  Discontinued         46.3  180 km
#
#       Efficiency_Wh_per_km  Fastcharge_kW Acceleration_0_100  Weight_kg  \
# ...

# %%
df.head()
# Out:
#       Brand            Model        Status  Battery_kWh   Range  \
# 0       BMW    iX3 50 xDrive     Available        108.7  610 km
# 1        MG  MG4 Electric 64     Available         61.7  360 km
# 2  Mercedes     Benz CLA 250     Available         85.0  585 km
# 3       BMW  iX xDrive40 BMW  Discontinued         71.0  360 km
# 4     Tesla     Model 3 Long     Available          NaN  580 km
#
#    Efficiency_Wh_per_km  Fastcharge_kW Acceleration_0_100  Weight_kg  \
# 0                   178          225.0            4.9 sec       2360
# 1                   171          115.0            7.9 sec       1726
# 2                   145          235.0            6.7 sec       2055
# 3                   197          102.0            6.1 sec       2440
# 4                   136          120.0            5.2 sec       1822
#
#   Price_Germany
# 0        68,900
# 1        39,990
# 2        55,859
# 3        77,300
# 4        45,970

# %%
df.tail()
# Out:
#         Brand                Model        Status  Battery_kWh   Range  \
# 1137      Kia            e-Niro 39  Discontinued         39.2  235 km
# 1138  Peugeot  e-Traveller Compact  Discontinued         46.3  185 km
# 1139     Ford       Mustang Mach-E  Discontinued         70.0  345 km
# 1140  Citroën                troën  Discontinued         46.3  185 km
# 1141  Citroën                troën  Discontinued         46.3  180 km
#
#       Efficiency_Wh_per_km  Fastcharge_kW Acceleration_0_100  Weight_kg  \
# 1137                   167           37.0            9.8 sec       1667
# 1138                   250           78.0           12.1 sec       1932
# 1139                   203           78.0            6.3 sec       2138
# 1140                   250           78.0           12.1 sec       1932
# 1141                   257           78.0           12.1 sec       1989
#
#      Price_Germany
# 1137        34,400
# 1138        50,880
# 1139        62,250
# 1140        49,080
# ...

# %%
df.sample(5)
# Out:
#         Brand                Model        Status  Battery_kWh   Range  \
# 839     Tesla    Model X Ludicrous  Discontinued          NaN  420 km
# 287      Audi            Q4 e-tron  Discontinued         76.6  385 km
# 279      Opel  Mokka Electric Opel     Available         50.8  285 km
# 1023  Porsche     Taycan GTS Sport     Available         97.0  505 km
# 837     Smart                  NaN     Available         62.0  325 km
#
#       Efficiency_Wh_per_km  Fastcharge_kW Acceleration_0_100  Weight_kg  \
# 839                    226          100.0            3.0 sec       2572
# 287                    199          115.0            6.2 sec       2210
# 279                    178           85.0            9.0 sec       1615
# 1023                   192          262.0            3.3 sec       2385
# 837                    191          100.0            4.5 sec       1975
#
#      Price_Germany
# 839        112,700
# 287         57,900
# 279         36,740
# 1023       148,600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1142 entries, 0 to 1141
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 1142 non-null   object
#  1   Model                 1123 non-null   object
#  2   Status                1142 non-null   object
#  3   Battery_kWh           911 non-null    float64
#  4   Range                 1142 non-null   object
#  5   Efficiency_Wh_per_km  1142 non-null   int64
#  6   Fastcharge_kW         1110 non-null   float64
#  7   Acceleration_0_100    1142 non-null   object
#  8   Weight_kg             1142 non-null   int64
#  9   Price_Germany         1055 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 98.1+ KB

# %% [markdown]
# checking for duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %%
df.drop_duplicates()
# Out:
#          Brand                Model        Status  Battery_kWh   Range  \
# 0          BMW        iX3 50 xDrive     Available        108.7  610 km
# 1           MG      MG4 Electric 64     Available         61.7  360 km
# 2     Mercedes         Benz CLA 250     Available         85.0  585 km
# 3          BMW      iX xDrive40 BMW  Discontinued         71.0  360 km
# 4        Tesla         Model 3 Long     Available          NaN  580 km
# ...        ...                  ...           ...          ...     ...
# 1137       Kia            e-Niro 39  Discontinued         39.2  235 km
# 1138   Peugeot  e-Traveller Compact  Discontinued         46.3  185 km
# 1139      Ford       Mustang Mach-E  Discontinued         70.0  345 km
# 1140   Citroën                troën  Discontinued         46.3  185 km
# 1141   Citroën                troën  Discontinued         46.3  180 km
#
#       Efficiency_Wh_per_km  Fastcharge_kW Acceleration_0_100  Weight_kg  \
# ...

# %% [markdown]
# Checking null values

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Status', 'Battery_kWh', 'Range',
#        'Efficiency_Wh_per_km', 'Fastcharge_kW', 'Acceleration_0_100',
#        'Weight_kg', 'Price_Germany'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Brand                     0
# Model                    19
# Status                    0
# Battery_kWh             231
# Range                     0
# Efficiency_Wh_per_km      0
# Fastcharge_kW            32
# Acceleration_0_100        0
# Weight_kg                 0
# Price_Germany            87
# dtype: int64

# %% [markdown]
# Filling the null values

# %%
#filling  missing model values  with "Unknown" values
df["Model"]=df["Model"].fillna("Unknown")

# %%
df["Model"].isna().sum()
# Out:
# np.int64(0)

# %%
#filling missing Battery_kWh values with median of Batter_kWh
df["Battery_kWh"].median()
# Out:
# 75.0

# %%
df["Battery_kWh"]=df["Battery_kWh"].fillna(df["Battery_kWh"].median())

# %%
df["Battery_kWh"].isna().sum()
# Out:
# np.int64(0)

# %%
#filling  missing Fastcharge_kW values with  median
df["Fastcharge_kW"].median()
# Out:
# 108.0

# %%
df["Fastcharge_kW"]=df["Fastcharge_kW"].fillna(df["Fastcharge_kW"].median())

# %%
df["Fastcharge_kW"].isna().sum()
# Out:
# np.int64(0)

# %%
#filling missing price valures with mediean
# clean and convert the column
df["Price_Germany"] = (df["Price_Germany"].astype(str).str.replace("€", "").str.replace(",", "").str.strip())

# %%
df["Price_Germany"].unique()
# Out:
# array(['68900', '39990', '55859', '77300', '45970', '34990', '39370',
#        '52990', '46450', '41390', '40970', '37990', '71281', '58990',
#        '53970', '32400', '55970', '44990', '32900', '31990', '44900',
#        '45560', '44180', '18900', '67300', '120970', '45690', '46335',
#        '81500', '51650', '47190', '31900', '60381', '55000', '109551',
#        '42990', '46600', '60970', '43240', '50970', '36840', '55480',
#        'nan', '25400', '53514', '66069', '47990', '32990', '59200',
#        '46380', '42900', '39000', '51500', '62970', '49421', '24990',
#        '30990', '38680', '35990', '69615', '37600', '47600', '38990',
#        '42290', '47900', '48900', '54000', '53990', '53668', '36900',
#        '48510', '118600', '53995', '35350', '38490', '58470', '51990',
#        '110970', '43500', '50777', '49990', '41990', '130900', '23300',
#        '51900', '45990', '55260', '125970', '42790', '69100', '100100',
# ...

# %%
df["Price_Germany"] = df["Price_Germany"].astype(float)

# %%
df["Price_Germany"].median()
# Out:
# 55859.0

# %%
df["Price_Germany"]=df["Price_Germany"].fillna(df["Price_Germany"].median())

# %%
df["Price_Germany"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# checking datatypes of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1142 entries, 0 to 1141
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 1142 non-null   object
#  1   Model                 1142 non-null   object
#  2   Status                1142 non-null   object
#  3   Battery_kWh           1142 non-null   float64
#  4   Range                 1142 non-null   object
#  5   Efficiency_Wh_per_km  1142 non-null   int64
#  6   Fastcharge_kW         1142 non-null   float64
#  7   Acceleration_0_100    1142 non-null   object
#  8   Weight_kg             1142 non-null   int64
#  9   Price_Germany         1142 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 98.1+ KB

# %%
#chaning Range datatype from str to int
df["Range"] = df["Range"].replace(r"[^\d.]", "", regex=True)  # keep only digits & decimal

# %%
df["Range"] = df["Range"].astype(int)

# %%
#chaning Fastcharge datatype from float to int
df["Fastcharge_kW"]=df["Fastcharge_kW"].astype(int)

# %%
#chaning  Acceleration_0_100  datatype from str to int
df["Acceleration_0_100"] = df["Acceleration_0_100"].replace(r"[^\d.]", "", regex=True) # keep only digits

# %%
df["Acceleration_0_100"] = df["Acceleration_0_100"].astype(float)

# %%
#chaning  Price_Germany  datatype from float to int
df["Price_Germany"]=df["Price_Germany"].astype(int)

# %%
df = df.rename(columns={"Price_Germany": "Price"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1142 entries, 0 to 1141
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 1142 non-null   object
#  1   Model                 1142 non-null   object
#  2   Status                1142 non-null   object
#  3   Battery_kWh           1142 non-null   float64
#  4   Range                 1142 non-null   int64
#  5   Efficiency_Wh_per_km  1142 non-null   int64
#  6   Fastcharge_kW         1142 non-null   int64
#  7   Acceleration_0_100    1142 non-null   float64
#  8   Weight_kg             1142 non-null   int64
#  9   Price                 1142 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 98.1+ KB

# %% [markdown]
# Data Analysis :

# %%
discrete_df=df.select_dtypes(include="object")

# %%
discrete_df
# Out:
#          Brand                Model        Status
# 0          BMW        iX3 50 xDrive     Available
# 1           MG      MG4 Electric 64     Available
# 2     Mercedes         Benz CLA 250     Available
# 3          BMW      iX xDrive40 BMW  Discontinued
# 4        Tesla         Model 3 Long     Available
# ...        ...                  ...           ...
# 1137       Kia            e-Niro 39  Discontinued
# 1138   Peugeot  e-Traveller Compact  Discontinued
# 1139      Ford       Mustang Mach-E  Discontinued
# 1140   Citroën                troën  Discontinued
# 1141   Citroën                troën  Discontinued
#
# [1142 rows x 3 columns]

# %%
def discrete(discrete_df):
    for col_name in discrete_df:
        print("*"*10,col_name,"*"*10)
        print(discrete_df[col_name].agg(['count','unique','nunique']))
        print()

# %%
discrete(discrete_df)
# Out:
# ********** Brand **********
# count                                                   1142
# unique     [BMW, MG, Mercedes, Tesla, Fiat, CUPRA, Kia, B...
# nunique                                                   74
# Name: Brand, dtype: object
#
# ********** Model **********
# count                                                   1142
# unique     [iX3 50 xDrive, MG4 Electric 64, Benz CLA 250,...
# nunique                                                  583
# Name: Model, dtype: object
#
# ********** Status **********
# count                           1142
# unique     [Available, Discontinued]
# nunique                            2
# Name: Status, dtype: object

# %%
numerical_df=df.select_dtypes(include="number") #"number" captures the int and float both

# %%
numerical_df
# Out:
#       Battery_kWh  Range  Efficiency_Wh_per_km  Fastcharge_kW  \
# 0           108.7    610                   178            225
# 1            61.7    360                   171            115
# 2            85.0    585                   145            235
# 3            71.0    360                   197            102
# 4            75.0    580                   136            120
# ...           ...    ...                   ...            ...
# 1137         39.2    235                   167             37
# 1138         46.3    185                   250             78
# 1139         70.0    345                   203             78
# 1140         46.3    185                   250             78
# 1141         46.3    180                   257             78
#
#       Acceleration_0_100  Weight_kg  Price
# 0                    4.9       2360  68900
# 1                    7.9       1726  39990
# 2                    6.7       2055  55859
# 3                    6.1       2440  77300
# ...

# %%
def numerical(numerical_df):
    for colu_name in numerical_df:
        print("*"*10,colu_name,"*"*10)
        print(numerical_df[colu_name].agg(['count','min','max','mean','median','std','skew']))
        print()

# %%
numerical(numerical_df)
# Out:
# ********** Battery_kWh **********
# count     1142.000000
# min         14.500000
# max        118.000000
# mean        72.425482
# median      75.000000
# std         18.382197
# skew        -0.309048
# Name: Battery_kWh, dtype: float64
#
# ********** Range **********
# count     1142.000000
# min         85.000000
# max        720.000000
# mean       374.518389
# median     385.000000
# std        113.602028
# skew        -0.282881
# Name: Range, dtype: float64
#
# ********** Efficiency_Wh_per_km **********
# count     1142.000000
# min        109.000000
# max        295.000000
# mean       191.202277
# median     184.000000
# std         29.581218
# skew         1.141896
# Name: Efficiency_Wh_per_km, dtype: float64
#
# ********** Fastcharge_kW **********
# count     1142.000000
# min          0.000000
# max        330.000000
# mean       113.732925
# median     108.000000
# std         55.348957
# skew         0.822614
# Name: Fastcharge_kW, dtype: float64
#
# ...

# %% [markdown]
#                                                            Data visualizations

# %% [markdown]
# Uni Variate Visual for Numerical columns

# %%
import math

def uni_variate_visual_num(data):
    num_cols = data.select_dtypes(include='number').columns
    n = len(num_cols)
    
    cols = 3 
    rows = math.ceil(n / cols)
    
    plt.figure(figsize=(cols * 10, rows * 10))

    for i, col in enumerate(num_cols, start=1):
        plt.subplot(rows, cols, i)
        sns.histplot(data=data, x=col,kde=True)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.grid(True)

    # plt.tight_layout()
    plt.show()
    num_cols = data.select_dtypes(include='number').columns
    n = len(num_cols)
    
    cols = 3 
    rows = math.ceil(n / cols)
    
    plt.figure(figsize=(cols * 10, rows * 10))

    for i, col in enumerate(num_cols, start=1):
        plt.subplot(rows, cols, i)
        sns.histplot(data=data, x=col,kde=True)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.grid(True)

    # plt.tight_layout()
    plt.show()

# %%
uni_variate_visual_num(numerical_df)

# %% [markdown]
# uni variate visual using Boxplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

def uni_variate_visual_boxplot(data):
    num_cols = data.select_dtypes(include='number').columns
    n = len(num_cols)
    
    cols = 3  # Number of plots per row
    rows = math.ceil(n / cols)

    plt.figure(figsize=(cols * 6, rows * 5))  # Adjust size as needed

    for i, col in enumerate(num_cols, start=1):
        plt.subplot(rows, cols, i)
        sns.boxplot(data=data, y=col)  # <- BOX PLOT here, not histplot
        plt.title(f"Box Plot of {col}")
        plt.ylabel(col)
        plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
uni_variate_visual_boxplot(numerical_df)

# %% [markdown]
# Uni variate visual for  categorical colmuns

# %%
def uni_variate_visual_cat(data):
    num_cols = data.select_dtypes(include='object').columns
    n = len(num_cols)
    
    cols = 3 
    rows = math.ceil(n / cols)
    
    plt.figure(figsize=(cols * 10, rows * 10))

    for i, col in enumerate(num_cols, start=1):
        plt.subplot(rows, cols, i)
        sns.countplot(data=data, x=col)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.xticks(rotation=45)
        plt.legend()
        plt.grid(True)

    plt.show()

# %%
uni_variate_visual_cat(discrete_df)
# Out:
# C:\Users\Vijay Golliwar\AppData\Local\Temp\ipykernel_23600\3724431154.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Vijay Golliwar\AppData\Local\Temp\ipykernel_23600\3724431154.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Vijay Golliwar\AppData\Local\Temp\ipykernel_23600\3724431154.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Bivariate Analysis (Continuous vs Continuous)

# %%
#Range in KM vs Price Euros (€)
plt.figure(figsize=(8,6))
sns.scatterplot(x="Range", y="Price", data=df, hue="Status", alpha=0.7)
plt.title("Range vs Price (Scatter Plot)")
plt.xlabel("Range in KM")
plt.ylabel("Price Euros (€)")
plt.show()

# %%
corr_price = df["Range"].corr(df["Price"])
print("Bivariate (Continuous vs Continuous) Insight:")
print(f"- There is a positive correlation (r = {corr_price:.2f}) between Range and Price.\n")
# Out:
# Bivariate (Continuous vs Continuous) Insight:
# - There is a positive correlation (r = 0.53) between Range and Price.

# %% [markdown]
# Bivariate Analysis (Continuous vs Categorical)

# %%
# Price vs Status(car is Available, Discontinued)

plt.figure(figsize=(8,6))
sns.boxplot(x='Status', y='Price', data=df)
plt.title("Price Distribution by Car Status")
plt.xlabel("Car Status")
plt.ylabel("Price (€)")
plt.show()

# %% [raw]
# This means currently available cars cost more than discontinued ones, likely because discontinued models are older or less in demand.
